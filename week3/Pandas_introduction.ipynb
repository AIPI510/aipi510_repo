# %% [markdown]
# <a href='https://ai.meng.duke.edu'> = <img align="left" style="padding-top:10px;" src=https://storage.googleapis.com/aipi_datasets/Duke-AIPI-Logo.png>

# %% [markdown]
# # Introduction to pandas
# Data used in this exercise has been modified from the winemag-data-130k file from Kaggle: https://www.kaggle.com/christopheiv/winemagdata130k

# %%
# Run this before any other code cell
# This downloads the csv data files into the same directory where you have saved this notebook

import urllib.request
from pathlib import Path
import os
path = Path()

# Dictionary of file names and download links
files = {'wine-ratings.csv':'https://storage.googleapis.com/aipi_datasets/wine-ratings.csv',
        'wineries.csv':'https://storage.googleapis.com/aipi_datasets/wineries.csv'}

# Download each file
for key,value in files.items():
    filename = path/key
    url = value
    # If the file does not already exist in the directory, download it
    if not os.path.exists(filename):
        urllib.request.urlretrieve(url,filename)

# %% [markdown]
# ### Create a simple DataFrame

# %%
# We commonly import pandas as pd.  We can then use pandas commands by pd.function_name()
import pandas as pd
import numpy as np

# Disable pandas warnings
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# Create a DataFrame from a dictionary of lists
population = [38332521, 26448193, 19651127, 19552860, 12882135]
area = [423967, 170312, 149995, 141297, 695662]
state_names = ['California','Florida','Illinois','New York','Texas']
states_df = pd.DataFrame({'Population':population,'Area':area},index=state_names) # Index specifies row names
states_df
# Out:
#             Population    Area
# California    38332521  423967
# Florida       26448193  170312
# Illinois      19651127  149995
# New York      19552860  141297
# Texas         12882135  695662

# %%
# Create a DataFrame from a 2D NumPy array.  You can define the index and column names using lists
state_array = np.array([[38332521,423967],[26448193,170312],[19651127,149995],[19552860,141297],[12882135,695662]])
state_names = ['California','Florida','Illinois','New York','Texas']
states_df = pd.DataFrame(state_array,index=state_names,columns=['Population','Area'])
states_df
# Out:
#             Population    Area
# California    38332521  423967
# Florida       26448193  170312
# Illinois      19651127  149995
# New York      19552860  141297
# Texas         12882135  695662

# %% [markdown]
# # Gather data
# ### Read in data from a file
# Pandas can read in data from a number of different file formats (even Excel files!).  The most common formats we will use are csv files and txt files. Pandas is usually able to infer the header (column names) of the data.  If you know that your file contains dates which you would like pandas to automatically parse into its datetime format, you can set parse_dates=True

# %%
# Read in file using pd.read_csv()
wine_df = pd.read_csv('wine-ratings.csv')

# Display the first n rows (default is 5 rows)
wine_df.head()
# Out:
#    Unnamed: 0                                        description  \
# 0           0  Aromas include tropical fruit, broom, brimston...
# 1           1  This is ripe and fruity, a wine that is smooth...
# 2           2  Tart and snappy, the flavors of lime flesh and...
# 3           3  Pineapple rind, lemon pith and orange blossom ...
# 4           4  Much like the regular bottling from 2012, this...
#
#                           designation  points  price             region_1  \
# 0                        Vulkà Bianco      87    NaN                 Etna
# 1                            Avidagos      87   15.0                  NaN
# 2                                 NaN      87   14.0    Willamette Valley
# 3                Reserve Late Harvest      87   13.0  Lake Michigan Shore
# 4  Vintner's Reserve Wild Child Block      87   65.0    Willamette Valley
#
#           taster_name taster_twitter_handle  \
# 0       Kerin O’Keefe          @kerinokeefe
# 1          Roger Voss            @vossroger
# 2        Paul Gregutt           @paulgwine
# 3  Alexander Peartree                   NaN
# 4        Paul Gregutt           @paulgwine
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos
# 2            Rainstorm
# 3           St. Julian
# 4         Sweet Cheeks

# %% [markdown]
# ### Understand data structure and contents

# %%
# Display shape of data
wine_df.shape
# Out:
# (129971, 11)

# %%
# Get type of each column
wine_df.dtypes
# Out:
# Unnamed: 0                 int64
# description               object
# designation               object
# points                     int64
# price                    float64
# region_1                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
# Get statistics on any numerical columns
wine_df.describe()
# Out:
#           Unnamed: 0         points          price
# count  129971.000000  129971.000000  120975.000000
# mean    64985.000000      88.447138      35.363389
# std     37519.540256       3.039730      41.022218
# min         0.000000      80.000000       4.000000
# 25%     32492.500000      86.000000      17.000000
# 50%     64985.000000      88.000000      25.000000
# 75%     97477.500000      91.000000      42.000000
# max    129970.000000     100.000000    3300.000000

# %%
# We can use .unique() and .nunique() to look at the unique values in a column
# E.g. how many different tasters are there?
wine_df['taster_name'].nunique()
# Out:
# 19

# %%
# What are the names of the different tasters?
wine_df['taster_name'].unique()
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams',
#        'Christina Pickard'], dtype=object)

# %% [markdown]
# ### Combine dataframes
# We can see above that our wine_df dataframe contains information on the winery and region for each wine, but what if we want to know where each wine is from? We can import another file which contains a list of all the wineries and associated location.  We then have to merge this dataframe to our original wine_df.

# %%
# Read in the dataframe containing winery locations
wineries = pd.read_csv('wineries.csv')
wineries.head()
# Out:
#                 winery             region_1           province   country
# 0              Nicosia                 Etna  Sicily & Sardinia     Italy
# 1  Quinta dos Avidagos                  NaN              Douro  Portugal
# 2            Rainstorm    Willamette Valley             Oregon        US
# 3           St. Julian  Lake Michigan Shore           Michigan        US
# 4         Sweet Cheeks    Willamette Valley             Oregon        US

# %%
# Merge wineries onto wines_df
# We can see they share two common columns: 'winery' and 'region_1' so let's use both as the merge keys
# We will do a left merge to preserve all entries in the left dataframe (wine_df) even if there is no corresponding
# entry in the right dataframe (wineries)
wines_wlocations = wine_df.merge(wineries,how='left',on=['winery','region_1'])

# Display the head of our new merged df
wines_wlocations.head()
# Out:
#    Unnamed: 0                                        description  \
# 0           0  Aromas include tropical fruit, broom, brimston...
# 1           1  This is ripe and fruity, a wine that is smooth...
# 2           2  Tart and snappy, the flavors of lime flesh and...
# 3           3  Pineapple rind, lemon pith and orange blossom ...
# 4           4  Much like the regular bottling from 2012, this...
#
#                           designation  points  price             region_1  \
# 0                        Vulkà Bianco      87    NaN                 Etna
# 1                            Avidagos      87   15.0                  NaN
# 2                                 NaN      87   14.0    Willamette Valley
# 3                Reserve Late Harvest      87   13.0  Lake Michigan Shore
# 4  Vintner's Reserve Wild Child Block      87   65.0    Willamette Valley
#
#           taster_name taster_twitter_handle  \
# 0       Kerin O’Keefe          @kerinokeefe
# 1          Roger Voss            @vossroger
# 2        Paul Gregutt           @paulgwine
# 3  Alexander Peartree                   NaN
# 4        Paul Gregutt           @paulgwine
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery           province   country
# 0              Nicosia  Sicily & Sardinia     Italy
# 1  Quinta dos Avidagos              Douro  Portugal
# 2            Rainstorm             Oregon        US
# 3           St. Julian           Michigan        US
# 4         Sweet Cheeks             Oregon        US

# %% [markdown]
# ### Simplify and clean up columns
# We often want to simplify the columns of our dataframe to remove duplicate or unnecessary data from the raw data.  We can do this using the pandas drop() command

# %%
# In our dataframe we have a duplicate index column ("Unnamed: 0").  Let's remove it
wines_wlocations = wines_wlocations.drop(labels=['Unnamed: 0'],axis=1) # Set axis 1 to drop it from columns
wines_wlocations.head()
# Out:
#                                          description  \
# 0  Aromas include tropical fruit, broom, brimston...
# 1  This is ripe and fruity, a wine that is smooth...
# 2  Tart and snappy, the flavors of lime flesh and...
# 3  Pineapple rind, lemon pith and orange blossom ...
# 4  Much like the regular bottling from 2012, this...
#
#                           designation  points  price             region_1  \
# 0                        Vulkà Bianco      87    NaN                 Etna
# 1                            Avidagos      87   15.0                  NaN
# 2                                 NaN      87   14.0    Willamette Valley
# 3                Reserve Late Harvest      87   13.0  Lake Michigan Shore
# 4  Vintner's Reserve Wild Child Block      87   65.0    Willamette Valley
#
#           taster_name taster_twitter_handle  \
# 0       Kerin O’Keefe          @kerinokeefe
# 1          Roger Voss            @vossroger
# 2        Paul Gregutt           @paulgwine
# 3  Alexander Peartree                   NaN
# 4        Paul Gregutt           @paulgwine
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery           province   country
# 0              Nicosia  Sicily & Sardinia     Italy
# 1  Quinta dos Avidagos              Douro  Portugal
# 2            Rainstorm             Oregon        US
# 3           St. Julian           Michigan        US
# 4         Sweet Cheeks             Oregon        US

# %% [markdown]
# We often want to rename columns so that they make more sense.  We can do this with the rename() command

# %%
# Let's rename the "title" column to "name" 
wines_wlocations.rename(columns={'title':'name'},inplace=True) # Specify inplace=True to perform it on original df
wines_wlocations.head()
# Out:
#                                          description  \
# 0  Aromas include tropical fruit, broom, brimston...
# 1  This is ripe and fruity, a wine that is smooth...
# 2  Tart and snappy, the flavors of lime flesh and...
# 3  Pineapple rind, lemon pith and orange blossom ...
# 4  Much like the regular bottling from 2012, this...
#
#                           designation  points  price             region_1  \
# 0                        Vulkà Bianco      87    NaN                 Etna
# 1                            Avidagos      87   15.0                  NaN
# 2                                 NaN      87   14.0    Willamette Valley
# 3                Reserve Late Harvest      87   13.0  Lake Michigan Shore
# 4  Vintner's Reserve Wild Child Block      87   65.0    Willamette Valley
#
#           taster_name taster_twitter_handle  \
# 0       Kerin O’Keefe          @kerinokeefe
# 1          Roger Voss            @vossroger
# 2        Paul Gregutt           @paulgwine
# 3  Alexander Peartree                   NaN
# 4        Paul Gregutt           @paulgwine
#
#                                                 name         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery           province   country
# 0              Nicosia  Sicily & Sardinia     Italy
# 1  Quinta dos Avidagos              Douro  Portugal
# 2            Rainstorm             Oregon        US
# 3           St. Julian           Michigan        US
# 4         Sweet Cheeks             Oregon        US

# %% [markdown]
# # Validate data
# ### Changing types

# %%
# Reminder, you can view the type of all columns using .dtypes
wines_wlocations.dtypes
# Out:
# description               object
# designation               object
# points                     int64
# price                    float64
# region_1                  object
# taster_name               object
# taster_twitter_handle     object
# name                      object
# variety                   object
# winery                    object
# province                  object
# country                   object
# dtype: object

# %%
# Let's change the 'points' column from an int to a float
wines_wlocations['points'] = wines_wlocations['points'].astype(float)
wines_wlocations.dtypes
# Out:
# description               object
# designation               object
# points                   float64
# price                    float64
# region_1                  object
# taster_name               object
# taster_twitter_handle     object
# name                      object
# variety                   object
# winery                    object
# province                  object
# country                   object
# dtype: object

# %% [markdown]
# ### Remove missing data

# %%
# Check for missing data
wines_wlocations.isnull().sum()
# Out:
# description                  0
# designation              37465
# points                       0
# price                     8996
# region_1                 21247
# taster_name              26244
# taster_twitter_handle    31213
# name                         0
# variety                      1
# winery                       0
# province                    45
# country                     45
# dtype: int64

# %% [markdown]
# As we can see above, we have several columns which contain missing data. There are different ways to deal with this, but let's simply drop the rows which have certain data missing.

# %%
# Drop rows for which 'country' or 'price' is blank
wines_wloc_clean = wines_wlocations.dropna(axis=0,subset=['country','price']) # Axis=0 drops rows with missing values

# Check the original shape
print('Dataframe shape before removing missing data was {}'.format(wines_wlocations.shape))
# Check the new shape after dropping rows missing the country
print('Dataframe shape after removing missing data is {}'.format(wines_wloc_clean.shape))
# Out:
# Dataframe shape before removing missing data was (129971, 12)
# Dataframe shape after removing missing data is (120934, 12)

# %% [markdown]
# ### Create new derivative columns
# Let's say we want to define a new column 'points-price ratio' which stores the ratio of the wine's points to it's price.

# %%
# Define new column 'points-price ratio' as ratio of two existing columns 'points' and 'price'
wines_wloc_clean['points-price ratio'] = wines_wloc_clean['points'] / wines_wloc_clean['price']

wines_wloc_clean.head()
# Out:
#                                          description  \
# 1  This is ripe and fruity, a wine that is smooth...
# 2  Tart and snappy, the flavors of lime flesh and...
# 3  Pineapple rind, lemon pith and orange blossom ...
# 4  Much like the regular bottling from 2012, this...
# 5  Blackberry and raspberry aromas show a typical...
#
#                           designation  points  price             region_1  \
# 1                            Avidagos    87.0   15.0                  NaN
# 2                                 NaN    87.0   14.0    Willamette Valley
# 3                Reserve Late Harvest    87.0   13.0  Lake Michigan Shore
# 4  Vintner's Reserve Wild Child Block    87.0   65.0    Willamette Valley
# 5                        Ars In Vitro    87.0   15.0              Navarra
#
#           taster_name taster_twitter_handle  \
# 1          Roger Voss            @vossroger
# 2        Paul Gregutt           @paulgwine
# 3  Alexander Peartree                   NaN
# 4        Paul Gregutt           @paulgwine
# 5   Michael Schachner           @wineschach
#
#                                                 name             variety  \
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)      Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
#
#                 winery        province   country  points-price ratio
# 1  Quinta dos Avidagos           Douro  Portugal            5.800000
# 2            Rainstorm          Oregon        US            6.214286
# 3           St. Julian        Michigan        US            6.692308
# 4         Sweet Cheeks          Oregon        US            1.338462
# 5               Tandem  Northern Spain     Spain            5.800000

# %% [markdown]
# Now suppose we also want to create a column 'vintage_year' which contains the vintage year of the wine.  If we look at our dataframe, we can see that the year is contained in the 'name' column strings.  We will need to parse it out using a regular expression and store it in a new column.  We can use the .map() method to map a lambda function (for example, containing a regular expression in this case) to each row of the dataframe

# %%
# Create a new column 'vintage_year' that parses the year from the 'name' column

import re # Import regular expressions

# Write a function to find a pattern of 4 digits in a string (first two being 19 or 20)
# Return the first instance of the pattern as 'year'
def find_year(x):
    pattern = r'\b(19)\d{2}\b|\b(20)\d{2}\b' # regular expression pattern for 4 digits in a row
    m = re.search(pattern,x) # Searches the input string x for the pattern
    year = m.group() if m else None # Sets 'year' to the first found instance of the pattern
    return year

# Apply this function to the 'name' column using the .map() method
wines_wloc_clean['vintage_year'] = wines_wloc_clean['name'].map(lambda x: find_year(x))

wines_wloc_clean.head()
# Out:
#                                          description  \
# 1  This is ripe and fruity, a wine that is smooth...
# 2  Tart and snappy, the flavors of lime flesh and...
# 3  Pineapple rind, lemon pith and orange blossom ...
# 4  Much like the regular bottling from 2012, this...
# 5  Blackberry and raspberry aromas show a typical...
#
#                           designation  points  price             region_1  \
# 1                            Avidagos    87.0   15.0                  NaN
# 2                                 NaN    87.0   14.0    Willamette Valley
# 3                Reserve Late Harvest    87.0   13.0  Lake Michigan Shore
# 4  Vintner's Reserve Wild Child Block    87.0   65.0    Willamette Valley
# 5                        Ars In Vitro    87.0   15.0              Navarra
#
#           taster_name taster_twitter_handle  \
# 1          Roger Voss            @vossroger
# 2        Paul Gregutt           @paulgwine
# 3  Alexander Peartree                   NaN
# 4        Paul Gregutt           @paulgwine
# 5   Michael Schachner           @wineschach
#
#                                                 name             variety  \
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)      Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
#
#                 winery        province   country  points-price ratio  \
# 1  Quinta dos Avidagos           Douro  Portugal            5.800000
# 2            Rainstorm          Oregon        US            6.214286
# 3           St. Julian        Michigan        US            6.692308
# 4         Sweet Cheeks          Oregon        US            1.338462
# 5               Tandem  Northern Spain     Spain            5.800000
#
#   vintage_year
# 1         2011
# 2         2013
# 3         2013
# 4         2012
# 5         2011

# %% [markdown]
# # Explore data
# ### Slicing data
# We slice data in pandas using one of two ways:
#     1) Using the integer index values and .iloc[ ]
#     2) Using the labeled string indices and .loc[ ]

# %%
# Use iloc with integer to get row based on index position
wines_wloc_clean.iloc[1]
# Out:
# description              Tart and snappy, the flavors of lime flesh and...
# designation                                                            NaN
# points                                                                  87
# price                                                                   14
# region_1                                                 Willamette Valley
# taster_name                                                   Paul Gregutt
# taster_twitter_handle                                          @paulgwine
# name                         Rainstorm 2013 Pinot Gris (Willamette Valley)
# variety                                                         Pinot Gris
# winery                                                           Rainstorm
# province                                                            Oregon
# country                                                                 US
# points-price ratio                                                 6.21429
# vintage_year                                                          2013
# Name: 2, dtype: object

# %%
# Use loc to get row based on index name (in this case we get the row with index name '1')
wines_wloc_clean.loc[1]
# Out:
# description              This is ripe and fruity, a wine that is smooth...
# designation                                                       Avidagos
# points                                                                  87
# price                                                                   15
# region_1                                                               NaN
# taster_name                                                     Roger Voss
# taster_twitter_handle                                           @vossroger
# name                         Quinta dos Avidagos 2011 Avidagos Red (Douro)
# variety                                                     Portuguese Red
# winery                                                 Quinta dos Avidagos
# province                                                             Douro
# country                                                           Portugal
# points-price ratio                                                     5.8
# vintage_year                                                          2011
# Name: 1, dtype: object

# %%
# Get the first three columns in the dataframe using .iloc[ ]
wines_wloc_clean.iloc[:,:3]
# Out:
#                                               description  \
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# 5       Blackberry and raspberry aromas show a typical...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points
# 1                                     Avidagos    87.0
# 2                                          NaN    87.0
# 3                         Reserve Late Harvest    87.0
# 4           Vintner's Reserve Wild Child Block    87.0
# 5                                 Ars In Vitro    87.0
# ...                                        ...     ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese    90.0
# 129967                                     NaN    90.0
# 129968                                   Kritt    90.0
# 129969                                     NaN    90.0
# 129970           Lieu-dit Harth Cuvée Caroline    90.0
#
# [120934 rows x 3 columns]

# %%
# Get the first three columns in the dataframe using .loc[ ]
wines_wloc_clean.loc[:,['description','designation','points']]
# Out:
#                                               description  \
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# 5       Blackberry and raspberry aromas show a typical...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points
# 1                                     Avidagos    87.0
# 2                                          NaN    87.0
# 3                         Reserve Late Harvest    87.0
# 4           Vintner's Reserve Wild Child Block    87.0
# 5                                 Ars In Vitro    87.0
# ...                                        ...     ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese    90.0
# 129967                                     NaN    90.0
# 129968                                   Kritt    90.0
# 129969                                     NaN    90.0
# 129970           Lieu-dit Harth Cuvée Caroline    90.0
#
# [120934 rows x 3 columns]

# %% [markdown]
# ### Filtering data

# %% [markdown]
# We can use Boolean masks to filter dataframes based on conditions.

# %%
# Filter the dataframe to get all wines produced in the US
US_wines = wines_wloc_clean[wines_wloc_clean['country']=='US']

US_wines.head()
# Out:
#                                           description  \
# 2   Tart and snappy, the flavors of lime flesh and...
# 3   Pineapple rind, lemon pith and orange blossom ...
# 4   Much like the regular bottling from 2012, this...
# 10  Soft, supple plum envelopes an oaky structure ...
# 12  Slightly reduced, this wine offers a chalky, t...
#
#                            designation  points  price             region_1  \
# 2                                  NaN    87.0   14.0    Willamette Valley
# 3                 Reserve Late Harvest    87.0   13.0  Lake Michigan Shore
# 4   Vintner's Reserve Wild Child Block    87.0   65.0    Willamette Valley
# 10                      Mountain Cuvée    87.0   19.0          Napa Valley
# 12                                 NaN    87.0   34.0     Alexander Valley
#
#            taster_name taster_twitter_handle  \
# 2         Paul Gregutt           @paulgwine
# 3   Alexander Peartree                   NaN
# 4         Paul Gregutt           @paulgwine
# 10      Virginie Boone               @vboone
# 12      Virginie Boone               @vboone
#
#                                                  name             variety  \
# 2       Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 3   St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4   Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 10  Kirkland Signature 2011 Mountain Cuvée Caberne...  Cabernet Sauvignon
# 12  Louis M. Martini 2012 Cabernet Sauvignon (Alex...  Cabernet Sauvignon
#
#                 winery    province country  points-price ratio vintage_year
# 2            Rainstorm      Oregon      US            6.214286         2013
# 3           St. Julian    Michigan      US            6.692308         2013
# 4         Sweet Cheeks      Oregon      US            1.338462         2012
# 10  Kirkland Signature  California      US            4.578947         2011
# 12    Louis M. Martini  California      US            2.558824         2012

# %% [markdown]
# We can also use multiple conditions together to filter a dataframe

# %%
# Filter the dataframe to get all wines produced in France with a point score > 90
Best_french_wines = wines_wloc_clean[(wines_wloc_clean['country']=='France') & (wines_wloc_clean['points']>90)]

Best_french_wines.head()
# Out:
#                                            description  \
# 119  Medium-gold in color. Complex and inviting nos...
# 126  Mid-gold color. Pronounced and enticing aromas...
# 127  Attractive mid-gold color with intense aromas ...
# 128  Compelling minerality on the nose, Refined and...
# 131  Attractive mid-gold color. Compelling layers o...
#
#                                     designation  points  price region_1  \
# 119  Schoenenbourg Grand Cru Vendanges Tardives    92.0   80.0   Alsace
# 126                           Vendages Tardives    91.0   48.0   Alsace
# 127                                  Alsace One    91.0   13.0   Alsace
# 128                                         NaN    91.0   17.0   Alsace
# 131                                      Gentil    91.0   20.0   Alsace
#
#     taster_name taster_twitter_handle  \
# 119         NaN                   NaN
# 126         NaN                   NaN
# 127         NaN                   NaN
# 128         NaN                   NaN
# 131         NaN                   NaN
#
#                                                   name             variety  \
# 119  Dopff & Irion 2004 Schoenenbourg Grand Cru Ven...            Riesling
# 126  Pierre Sparr 2007 Vendages Tardives Gewurztram...      Gewürztraminer
# 127        Pierre Sparr 2008 Alsace One White (Alsace)         White Blend
# 128               Kuentz-Bas 2008 Pinot Blanc (Alsace)         Pinot Blanc
# 131           Dopff & Irion 2008 Gentil White (Alsace)  Alsace white blend
#
#             winery province country  points-price ratio vintage_year
# 119  Dopff & Irion   Alsace  France            1.150000         2004
# 126   Pierre Sparr   Alsace  France            1.895833         2007
# 127   Pierre Sparr   Alsace  France            7.000000         2008
# 128     Kuentz-Bas   Alsace  France            5.352941         2008
# 131  Dopff & Irion   Alsace  France            4.550000         2008

# %% [markdown]
# ### Sorting data

# %% [markdown]
# Let's sort our US_wines dataframe by 'points-price ratio' to see which American wine gives us the best ratio of quality to price

# %%
# Sort the dataframe by 'points-price ratio'. Set ascending=False to display highest values first
US_wines.sort_values(by='points-price ratio',ascending=False)
# Out:
#                                               description  \
# 64590   There's a lot going on in this Merlot, which i...
# 20484   Fruity, soft and rather sweet, this wine smell...
# 31530   Packaged in a cute yellow recyclable Tetrapak,...
# 110255  A good everyday Merlot, dry and rich in tannin...
# 59507   Sweet and fruity, this canned wine feels soft ...
# ...                                                   ...
# 38978   We can debate the pricing on Yao Ming's new re...
# 83852   The former basketball star's initial release i...
# 25382   As imposing as the athlete himself, this is an...
# 51978   This is a powerful bottling, as is expected by...
# 120391  The nose on this single-vineyard wine from a s...
#
#                 designation  points   price     region_1     taster_name  \
# 64590                   NaN    86.0     4.0   California             NaN
# 20484                   NaN    85.0     4.0   Clarksburg      Jim Gordon
# 31530                   NaN    84.0     4.0   California             NaN
# 110255                  NaN    84.0     4.0   California             NaN
# 59507               Unoaked    83.0     4.0   California      Jim Gordon
# ...                     ...     ...     ...          ...             ...
# 38978        Family Reserve    98.0   625.0  Napa Valley             NaN
# 83852        Family Reserve    97.0   625.0  Napa Valley             NaN
# 25382        Family Reserve    94.0   625.0  Napa Valley  Virginie Boone
# 51978              Intrepid    92.0   750.0  Paso Robles   Matt Kettmann
# 120391  Roger Rose Vineyard    91.0  2013.0  Arroyo Seco   Matt Kettmann
#
#        taster_twitter_handle  \
# 64590                    NaN
# 20484       @gordone_cellars
# 31530                    NaN
# 110255                   NaN
# 59507       @gordone_cellars
# ...                      ...
# 38978                    NaN
# 83852                    NaN
# 25382                @vboone
# 51978          @mattkettmann
# 120391         @mattkettmann
#
#                                                      name             variety  \
# 64590                       Bandit NV Merlot (California)              Merlot
# 20484              Dancing Coyote 2015 White (Clarksburg)         White Blend
# 31530                   Bandit NV Chardonnay (California)          Chardonnay
# 110255                      Bandit NV Merlot (California)              Merlot
# 59507     Pam's Cuties NV Unoaked Chardonnay (California)          Chardonnay
# ...                                                   ...                 ...
# 38978   Yao Ming 2010 Family Reserve Cabernet Sauvigno...  Cabernet Sauvignon
# 83852   Yao Ming 2009 Family Reserve Cabernet Sauvigno...  Cabernet Sauvignon
# 25382   Yao Ming 2011 Family Reserve Cabernet Sauvigno...  Cabernet Sauvignon
# 51978               Law 2013 Intrepid Syrah (Paso Robles)               Syrah
# 120391  Blair 2013 Roger Rose Vineyard Chardonnay (Arr...          Chardonnay
#
#                 winery    province country  points-price ratio vintage_year
# 64590           Bandit  California      US           21.500000         None
# 20484   Dancing Coyote  California      US           21.250000         2015
# 31530           Bandit  California      US           21.000000         None
# 110255          Bandit  California      US           21.000000         None
# 59507     Pam's Cuties  California      US           20.750000         None
# ...                ...         ...     ...                 ...          ...
# 38978         Yao Ming  California      US            0.156800         2010
# 83852         Yao Ming  California      US            0.155200         2009
# 25382         Yao Ming  California      US            0.150400         2011
# 51978              Law  California      US            0.122667         2013
# 120391           Blair  California      US            0.045206         2013
#
# [54267 rows x 14 columns]

# %% [markdown]
# ### Grouping data and aggregations

# %% [markdown]
# We can use the pandas groupby() method to group data according to common values in one or more columns

# %%
# Let's see which country's wines have the highest points
# Group the dataframe by country and display the mean 'points' score for each country's wines
groups = wines_wloc_clean.groupby('country')
groups['points'].mean()
# Out:
# country
# Argentina                 86.710330
# Armenia                   87.500000
# Australia                 88.595466
# Austria                   90.188612
# Bosnia and Herzegovina    86.500000
# Brazil                    84.659574
# Bulgaria                  87.936620
# Canada                    89.377953
# Chile                     86.499548
# China                     89.000000
# Croatia                   87.273973
# Cyprus                    87.181818
# Czech Republic            87.250000
# England                   91.550725
# France                    88.734867
# Georgia                   87.714286
# Germany                   89.838208
# Greece                    87.290393
# Hungary                   89.228571
# India                     90.222222
# Israel                    88.521298
# Italy                     88.618186
# Lebanon                   87.685714
# Luxembourg                88.666667
# Macedonia                 86.833333
# Mexico                    85.257143
# Moldova                   87.203390
# Morocco                   88.482759
# New Zealand               88.300364
# Peru                      83.562500
# Portugal                  88.318135
# Romania                   86.394958
# Serbia                    87.500000
# Slovakia                  87.000000
# Slovenia                  88.088608
# South Africa              87.829475
# Spain                     87.290735
# Switzerland               88.571429
# Turkey                    88.088889
# US                        88.566440
# Ukraine                   84.071429
# Uruguay                   86.745455
# Name: points, dtype: float64

# %%
# Display the number of wines per country in the dataset using value_counts()
wines_wloc_clean['country'].value_counts()
# Out:
# US                        54267
# France                    17776
# Italy                     16914
# Spain                      6573
# Portugal                   4869
# Chile                      4428
# Argentina                  3756
# Austria                    2810
# Australia                  2294
# Germany                    2120
# New Zealand                1375
# South Africa               1296
# Israel                      493
# Greece                      458
# Canada                      254
# Bulgaria                    142
# Hungary                     140
# Romania                     119
# Uruguay                     110
# Turkey                       90
# Georgia                      84
# Slovenia                     79
# Croatia                      73
# Mexico                       70
# England                      69
# Moldova                      59
# Brazil                       47
# Lebanon                      35
# Morocco                      29
# Peru                         16
# Ukraine                      14
# Czech Republic               12
# Macedonia                    12
# Serbia                       12
# Cyprus                       11
# India                         9
# Switzerland                   7
# Luxembourg                    6
# Bosnia and Herzegovina        2
# Armenia                       2
# China                         1
# Slovakia                      1
# Name: country, dtype: int64

# %% [markdown]
# After grouping, we can also use the `agg()` method to compute multiple aggregate statistics on the groups

# %%
# Let's look at the reviews by taster and see if there are any notable differences in points awarded
groups = wines_wloc_clean.groupby('taster_name')
groups['points'].agg(['count','min','median','max'])
# Out:
#                     count   min  median    max
# taster_name
# Alexander Peartree    413  80.0    86.0   91.0
# Anna Lee C. Iijima   4369  80.0    88.0   98.0
# Anne Krebiehl MW     3398  80.0    90.0   97.0
# Carrie Dykes          138  81.0    87.0   92.0
# Christina Pickard       6  82.0    88.0   93.0
# Fiona Adams            27  82.0    87.0   91.0
# Jeff Jenssen          470  82.0    89.0   97.0
# Jim Gordon           4171  80.0    89.0   97.0
# Joe Czerwinski       5012  80.0    89.0  100.0
# Kerin O’Keefe        9874  80.0    89.0  100.0
# Lauren Buzzeo        1712  81.0    87.0   95.0
# Matt Kettmann        6237  81.0    90.0   97.0
# Michael Schachner   14948  80.0    87.0   98.0
# Mike DeSimone         496  82.0    89.0   94.0
# Paul Gregutt         9497  80.0    89.0  100.0
# Roger Voss          20172  80.0    88.0  100.0
# Sean P. Sullivan     4925  80.0    89.0   97.0
# Susan Kostrzewa      1066  80.0    87.0   94.0
# Virginie Boone       9507  80.0    90.0   99.0

# %% [markdown]
# ### Calculating statistics

# %%
# We can calculate statistics on individual rows, or use the describe() method
wines_wloc_clean.describe()
# Out:
#               points          price  points-price ratio
# count  120934.000000  120934.000000       120934.000000
# mean       88.421949      35.367407            3.840376
# std         3.044866      41.028377            2.216633
# min        80.000000       4.000000            0.026667
# 25%        86.000000      17.000000            2.119048
# 50%        88.000000      25.000000            3.458333
# 75%        91.000000      42.000000            5.117647
# max       100.000000    3300.000000           21.500000

# %% [markdown]
# ### Visualizations
# Visualizations are a great way to explore your data.  We will use the matplotlib library for visualizations, although there are other popular options such as seaborn or plotly.  In this exercise we will cover only a couple simple visualizations, but we will discuss visual analysis techniques in much greater detail in a later lecture.

# %%
# We generally import matplotlib as follows
import matplotlib.pyplot as plt

# %%
# Create a bar chart of the count of wines in the dataset by country

# Get the counts per vintage year
counts_by_year = wines_wloc_clean['vintage_year'].value_counts()
# Sort the vintage years
counts_by_year.sort_index(inplace=True)
counts_by_year
# Out:
# 1904        1
# 1919        1
# 1927        2
# 1929        6
# 1934        1
# 1935        1
# 1941        1
# 1945        1
# 1947        1
# 1952        2
# 1957        1
# 1961        1
# 1963        3
# 1964        2
# 1965        1
# 1966        1
# 1967        1
# 1968        1
# 1969        1
# 1973        1
# 1974        1
# 1976        1
# 1978        2
# 1980        2
# 1982        1
# 1983        2
# 1984        2
# 1985        4
# 1986        4
# 1987        2
# 1988        5
# 1989        6
# 1990        5
# 1991        4
# 1992       14
# 1993        3
# 1994       23
# 1995       45
# 1996       64
# 1997      297
# 1998      541
# 1999      619
# 2000      734
# 2001      668
# 2002      333
# 2003      499
# 2004     1604
# 2005     3292
# 2006     5170
# 2007     6498
# 2008     6725
# 2009     9056
# 2010    11102
# 2011    11434
# 2012    14735
# 2013    15190
# 2014    14881
# 2015     9626
# 2016     3549
# 2017       11
# Name: vintage_year, dtype: int64

# %%
# Generate a bar chart with the count for each year
plt.figure(figsize=(15,5))
plt.bar(x=counts_by_year.index, height = counts_by_year)
plt.xticks(rotation='60')
plt.title('Count of wines per vintage year')
plt.show()
